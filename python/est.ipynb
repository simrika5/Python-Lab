# %%
#Write a Python program to check whether a number is positive, negative, or zero using simple if statements.
number = float(input("Enter a number: "))
if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")

# %%
#    Write a Python program to determine whether a student has passed or failed based on marks entered by the user using if-else. 
marks = float(input("Enter the student's marks: "))
if marks >= 50:
    print("The student has passed.")
else:
    print("The student has failed.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 #    Write a Python program to determine whether a student has passed or failed based on marks entered by the user using if-else.
# ----> 2 marks = float(input("Enter the student's marks: "))
#       3 if marks >= 50:
#       4     print("The student has passed.")
#       5 else:
#
# ValueError: could not convert string to float: ''
